# %% [markdown]
# # DSC148 Kaggle Data Challenge
# Name: Yishan Cai

# %% [markdown]
# ## Set up

# %%
import pandas as pd
import numpy as np

from math import isnan
from catboost import CatBoostRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv('train.csv')
df.head(3)
# Out:
# /tmp/ipykernel_497/2051523488.py:1: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('train.csv')
#          id                                      name  \
# 0  22267382  Modern and Cozy Large Studio in Brooklyn
# 1   2473861          Royal Harlem TRIPLEX Home 5 Beds
# 2  25079703                 Sunny East Village Studio
#
#                                              summary  \
# 0  Modern large studio with new amenities and app...
# 1  Harlem is back and so gorgeous! Visit and expl...
# 2  Clean, hip and well designed sun drenched East...
#
#                                                space  \
# 0  Our place is a little quiet sanctuary in the h...
# 1  Harlem is back and so gorgeous! Visit and expl...
# 2  This is a rare East Village studio with it's h...
#
#                                          description experiences_offered  \
# 0  Modern large studio with new amenities and app...                none
# 1  Harlem is back and so gorgeous! Visit and expl...                none
# 2  Clean, hip and well designed sun drenched East...                none
#
#                                neighborhood_overview  \
# 0  BAM, Barclays, Brooklyn City Point, Fort Green...
# 1  HARLEM is a piece of real NY history overflowi...
# 2  East Village is one of the last remaining neig...
#
#                                                notes  \
# 0                                                NaN
# 1  HARLEM RESTAURANTS Red Rooster Harlem -- excel...
# 2                                                NaN
#
#                                              transit  \
# 0                          Subway: 2,3,4,5,A,C,B,Q,G
# 1  PUBLIC TRANSPORTATION: Conveniently near all p...
# 2                                                NaN
#
#                                               access  ...  \
# 0  Washer/Dryer Dishwasher Internet Gym Roof Top ...  ...
# 1                             The WHOLE ENTIRE HOUSE  ...
# 2  You'll have access to the entire space - it's ...  ...
#
#   review_scores_communication review_scores_location  review_scores_value  \
# 0                        10.0                   10.0                 10.0
# 1                         9.0                    9.0                  9.0
# 2                        10.0                   10.0                 10.0
#
#   instant_bookable is_business_travel_ready cancellation_policy  \
# 0                t                        f            flexible
# 1                t                        f            moderate
# 2                f                        f            moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
#
#   calculated_host_listings_count  reviews_per_month
# 0                              1               0.59
# 1                              3               2.47
# 2                              1               0.89
#
# [3 rows x 65 columns]

# %%
# number of observations
df.shape[0]
# Out:
# 33538

# %%
df_pp = df.copy()

# %% [markdown]
# ## one hot amenities & verifications

# %%
df_pp['host_since_year'] = pd.to_datetime(df_pp['host_since']).dt.year
df_pp['host_since_month'] = pd.to_datetime(df_pp['host_since']).dt.month
df_pp['host_since_day'] = pd.to_datetime(df_pp['host_since']).dt.day

# %%
df_pp['first_re_year'] = pd.to_datetime(df_pp['first_review']).dt.year
df_pp['first_re_month'] = pd.to_datetime(df_pp['first_review']).dt.month
df_pp['first_re_day'] = pd.to_datetime(df_pp['first_review']).dt.day
df_pp['last_re_year'] = pd.to_datetime(df_pp['last_review']).dt.year
df_pp['last_re_month'] = pd.to_datetime(df_pp['last_review']).dt.month
df_pp['last_re_day'] = pd.to_datetime(df_pp['last_review']).dt.day

# %%
all_amenities = set()
for amenities_str in df_pp['amenities']:
    amenities_list = amenities_str.strip('{}').split(',')
    for amenity in amenities_list:
        clean = amenity.strip().strip('"')
        all_amenities.add(clean)

all_amenities.discard('')

# %%
new_columns_data = {}
for idx, amenity in enumerate(all_amenities, start=1):
    new_columns_data[f'amenity_{idx}'] = df_pp['amenities'].apply(lambda x: 1 if amenity in x else 0)

df_pp = pd.concat([df_pp, pd.DataFrame(new_columns_data)], axis=1)

# %%
all_verifications = set()
for verifications_str in df_pp['host_verifications']:
    if isinstance(verifications_str, str):
        verifications_list = verifications_str.strip('[]').split(',')
        for verification in verifications_list:
            clean = verification.strip().strip("'")
            all_verifications.add(clean)

all_verifications.discard('')

veri_columns_data = {}
for idx, veri in enumerate(all_verifications, start=1):
    veri_columns_data[f'veri_{idx}'] = df_pp['host_verifications'].apply(lambda x: 1 if (isinstance(x, str) and veri in x) 
                                                                         else 0 if pd.isnull(x) else 0)

df_pp = pd.concat([df_pp, pd.DataFrame(veri_columns_data)], axis=1)

# %% [markdown]
# ## Pre-defined functions

# %%
def to_float(s):
    try:
        ret = float(s)
    except:
        ret = -1
    if isnan(ret):
        ret = -1
    return ret

def to_int(s):
    try:
        ret = int(s)
    except:
        ret = -1
    return ret

def to_len(s):
    try:
        ret = len(s)
    except:
        ret = 0
    if isnan(ret):
        ret = 0
    return ret

def to_label(s):
    if s is None:
        ret = 0
    else:
        ret = 1
    return ret

def to_num(value):
    if pd.isna(value):
        return -1
    else:
        return int(value[:-1])

def to_tf_label(s):
    if s is None:
        ret = -1
    elif s == 't':
        ret = 1
    else: 
        ret = 0
    return ret

# %%
ng_cate = [x for x in list(set(df['neighbourhood_group_cleansed'])) if type(x) is str]
neighbor_cate = [x for x in list(set(df['neighbourhood_cleansed'])) if type(x) is str]
room_cate = [x for x in list(set(df['room_type'])) if type(x) is str]
cancel_cate = [x for x in list(set(df['cancellation_policy'])) if type(x) is str]
property_cate = [x for x in list(set(df['property_type'])) if type(x) is str]
bed_cate = [x for x in list(set(df['bed_type'])) if type(x) is str]

# %%
def create_feature(row):
    
    len_name = to_len(row.name)
    len_summary = to_len(row.summary)
    len_space = to_len(row.space)
    len_description = to_len(row.description)
    len_notes = to_len(row.notes)
    len_nearby = to_len(row.neighborhood_overview)
    len_transit = to_len(row.transit)
    
    access = to_label(row.access)
    interact = to_label(row.interaction)
    rule = to_label(row.house_rules)
    len_hname = to_len(row.host_name)
    len_habout = to_len(row.host_about)
    host_response = to_num(row.host_response_rate)
    host_loco = to_label(row.host_location)
    superhost = to_tf_label(row.host_is_superhost)
    host_pic = to_tf_label(row.host_has_profile_pic)
    host_veri = to_tf_label(row.host_identity_verified)
    n_list = to_int(row.host_listings_count)
    n_clist = to_int(row.calculated_host_listings_count)
    zipcode = to_int(row.zipcode)
    host_join_year = to_int(row.host_since_year)
    host_join_month = to_int(row.host_since_month)
    host_join_day= to_int(row.host_since_day)
    
    guest_num = to_int(row.guests_included)
    guest_capa = to_int(row.extra_people)
    n_bedroom = to_int(row.bedrooms)
    n_bed = to_int(row.beds)
    n_bathroom = to_int(row.bathrooms)
    n_acco = to_int(row.accommodates)
    
    n_min_night = to_int(row.minimum_nights)
    n_max_night = to_int(row.maximum_nights)
    n_review = to_int(row.number_of_reviews)
    
    re_rate = to_float(row.review_scores_rating)
    re_accu = to_float(row.review_scores_accuracy)
    re_clean = to_float(row.review_scores_cleanliness)
    re_checkin = to_float(row.review_scores_checkin)
    re_comm = to_float(row.review_scores_communication)
    re_loca = to_float(row.review_scores_location)
    re_val = to_float(row.review_scores_value)
    re_per_month = to_float(row.reviews_per_month)
    
    first_re_year = to_int(row.first_re_year)
    last_re_year = to_int(row.last_re_year)
    first_re_month = to_int(row.first_re_month)
    last_re_month = to_int(row.last_re_month)
    first_re_day = to_int(row.first_re_day)
    last_re_day = to_int(row.last_re_day)
    
    instant_book = to_tf_label(row.instant_bookable)
    busi_travel = to_tf_label(row.is_business_travel_ready)
    guest_pic = to_tf_label(row.require_guest_profile_picture)
    guest_veri = to_tf_label(row.require_guest_phone_verification)

    
    one_hot_ng = [int(row.neighbourhood_group_cleansed == category) for category in ng_cate]
    one_hot_neighbor = [int(row.neighbourhood_cleansed == category) for category in neighbor_cate]
    one_hot_room = [int(row.room_type == category) for category in room_cate]
    one_hot_bed = [int(row.bed_type == category) for category in bed_cate]
    one_hot_cancel = [int(row.cancellation_policy == category) for category in cancel_cate]
    one_hot_proper = [int(row.property_type == category) for category in property_cate]
    
    result = [len_name, len_summary, len_space, len_description, len_notes, len_nearby, len_transit, 
              access, interact, rule, len_hname, len_habout, host_response, host_loco, superhost, 
              host_pic, host_veri, n_list, n_clist, zipcode, host_join_year, host_join_month, host_join_day, 
              guest_num, guest_capa, n_bedroom, n_bed, n_bathroom, n_acco, n_review, n_min_night, n_max_night, 
              re_rate, re_accu, re_clean, re_checkin, re_comm, re_loca, re_val, re_per_month, 
              first_re_year, last_re_year, first_re_month, last_re_month, first_re_day, last_re_day,
              instant_book, busi_travel, guest_pic, guest_veri,
              row.amenity_1, row.amenity_2, row.amenity_3, row.amenity_4, row.amenity_8, row.amenity_12,
              row.amenity_13, row.amenity_14, row.amenity_17, row.amenity_18, 
              row.amenity_19, row.amenity_22, row.amenity_23, row.amenity_24, row.amenity_27, 
              row.amenity_32, row.amenity_33, row.amenity_34, row.amenity_35, row.amenity_36,
              row.amenity_37,row.amenity_39, row.amenity_40,row.amenity_42,
              row.amenity_45,row.amenity_46,row.amenity_47,row.amenity_48,
              row.amenity_49,row.amenity_50,row.amenity_52,row.amenity_54,
              row.amenity_58,row.amenity_59,row.amenity_60,
              row.amenity_62,row.amenity_65,row.amenity_66,
              row.amenity_67,row.amenity_68,row.amenity_70,row.amenity_71,row.amenity_72,
              row.amenity_73,row.amenity_74,row.amenity_76,row.amenity_77,row.amenity_78,
              row.amenity_80,row.amenity_82,row.amenity_84,
              row.amenity_85,row.amenity_86,row.amenity_87,row.amenity_89,row.amenity_90,
              row.amenity_91,row.amenity_93,row.amenity_94,row.amenity_95,
              row.amenity_97,row.amenity_98,row.amenity_100,row.amenity_101,row.amenity_102,
              row.amenity_104,row.amenity_106,row.amenity_107,
              row.amenity_109,row.amenity_112,row.amenity_114,
              row.amenity_115,row.amenity_116,row.amenity_117,row.amenity_118,row.amenity_119,row.amenity_120,
              row.amenity_122,row.amenity_123,row.amenity_124,
              row.amenity_5, row.amenity_6, row.amenity_7, row.amenity_9,row.amenity_10, row.amenity_11, 
              row.amenity_15, row.amenity_16, row.amenity_20, row.amenity_21, row.amenity_25, row.amenity_26, 
              row.amenity_28, row.amenity_29, row.amenity_30,row.amenity_31, row.amenity_38,row.amenity_41,
              row.amenity_43,row.amenity_44,row.amenity_51,row.amenity_53,row.amenity_55,row.amenity_56,
              row.amenity_57,row.amenity_61,row.amenity_63,row.amenity_64,row.amenity_69,row.amenity_75, 
              row.amenity_79,row.amenity_81,row.amenity_83, row.amenity_88, row.amenity_92,row.amenity_96,
              row.amenity_99,row.amenity_103,row.amenity_105,row.amenity_108,row.amenity_110,
              row.amenity_111, row.amenity_113, row.amenity_121, row.amenity_125, 
              row.veri_1, row.veri_2, row.veri_3, row.veri_4, row.veri_5, row.veri_6,row.veri_7, 
              row.veri_8, row.veri_9, row.veri_10, row.veri_11, row.veri_12, row.veri_13, row.veri_14, row.veri_15, 
              row.veri_16, row.veri_17, row.veri_18, 
              row.veri_19] + one_hot_ng  + one_hot_neighbor + one_hot_bed + one_hot_cancel + one_hot_proper + one_hot_room

    return result

# %% [markdown]
# ### create features

# %%
train_X, train_y = [], []
for (idx, row) in df_pp.iterrows():
    price = float(row.price)
    feature = create_feature(row)

    train_X.append(feature)
    train_y.append(price)

print(len(train_X), len(train_y))
# Out:
# 33538 33538

# %% [markdown]
# ## For whole dataset

# %%
catboost_regr = CatBoostRegressor(iterations=1000, # Number of trees (boosting iterations)
                                   learning_rate=0.1, # Step size shrinkage used in update to prevent overfitting
                                   depth=7, # Depth of the trees
                                   loss_function='RMSE', # Loss function to optimize
                                   random_seed=42)

# %%
catboost_regr.fit(train_X, train_y)
# Out:
# 0:	learn: 127.5267460	total: 75ms	remaining: 1m 14s
# 1:	learn: 122.8421194	total: 105ms	remaining: 52.6s
# 2:	learn: 118.7132436	total: 135ms	remaining: 44.8s
# 3:	learn: 115.2136470	total: 162ms	remaining: 40.2s
# 4:	learn: 112.1597002	total: 193ms	remaining: 38.3s
# 5:	learn: 109.5372054	total: 223ms	remaining: 37s
# 6:	learn: 107.1986470	total: 253ms	remaining: 35.9s
# 7:	learn: 105.2054736	total: 283ms	remaining: 35.1s
# 8:	learn: 103.5492365	total: 309ms	remaining: 34s
# 9:	learn: 102.0062037	total: 343ms	remaining: 33.9s
# 10:	learn: 100.6886992	total: 378ms	remaining: 34s
# 11:	learn: 99.5189688	total: 418ms	remaining: 34.4s
# 12:	learn: 98.5107869	total: 445ms	remaining: 33.8s
# 13:	learn: 97.6040374	total: 476ms	remaining: 33.6s
# 14:	learn: 96.8477967	total: 507ms	remaining: 33.3s
# 15:	learn: 96.0689812	total: 535ms	remaining: 32.9s
# 16:	learn: 95.4052254	total: 562ms	remaining: 32.5s
# 17:	learn: 94.7801296	total: 597ms	remaining: 32.5s
# 18:	learn: 94.1609395	total: 624ms	remaining: 32.2s
# 19:	learn: 93.6891158	total: 651ms	remaining: 31.9s
# 20:	learn: 93.1505137	total: 677ms	remaining: 31.6s
# 21:	learn: 92.6269421	total: 705ms	remaining: 31.3s
# 22:	learn: 92.1868727	total: 739ms	remaining: 31.4s
# 23:	learn: 91.7275445	total: 763ms	remaining: 31s
# 24:	learn: 91.3485836	total: 784ms	remaining: 30.6s
# 25:	learn: 91.0082171	total: 805ms	remaining: 30.2s
# 26:	learn: 90.7235212	total: 830ms	remaining: 29.9s
# 27:	learn: 90.4155777	total: 860ms	remaining: 29.9s
# 28:	learn: 89.9910157	total: 886ms	remaining: 29.7s
# 29:	learn: 89.6330672	total: 912ms	remaining: 29.5s
# 30:	learn: 89.3732351	total: 937ms	remaining: 29.3s
# 31:	learn: 89.1370482	total: 959ms	remaining: 29s
# 32:	learn: 88.9400511	total: 982ms	remaining: 28.8s
# 33:	learn: 88.5981185	total: 1.01s	remaining: 28.6s
# 34:	learn: 88.4210990	total: 1.03s	remaining: 28.5s
# 35:	learn: 88.1014475	total: 1.06s	remaining: 28.4s
# 36:	learn: 87.8630991	total: 1.09s	remaining: 28.3s
# 37:	learn: 87.6896632	total: 1.11s	remaining: 28.2s
# 38:	learn: 87.5010235	total: 1.14s	remaining: 28.1s
# 39:	learn: 87.3014135	total: 1.16s	remaining: 28s
# 40:	learn: 87.1212106	total: 1.19s	remaining: 27.8s
# 41:	learn: 86.9327051	total: 1.22s	remaining: 27.7s
# 42:	learn: 86.7845593	total: 1.24s	remaining: 27.6s
# 43:	learn: 86.6192445	total: 1.26s	remaining: 27.5s
# 44:	learn: 86.4099351	total: 1.29s	remaining: 27.4s
# 45:	learn: 86.3371767	total: 1.31s	remaining: 27.3s
# 46:	learn: 86.1794085	total: 1.34s	remaining: 27.2s
# 47:	learn: 86.0318648	total: 1.37s	remaining: 27.1s
# 48:	learn: 85.8907118	total: 1.39s	remaining: 27s
# 49:	learn: 85.7701786	total: 1.42s	remaining: 27s
# 50:	learn: 85.6177449	total: 1.45s	remaining: 26.9s
# 51:	learn: 85.5377638	total: 1.47s	remaining: 26.8s
# 52:	learn: 85.3985959	total: 1.5s	remaining: 26.7s
# 53:	learn: 85.2968879	total: 1.52s	remaining: 26.7s
# 54:	learn: 85.2474532	total: 1.55s	remaining: 26.6s
# 55:	learn: 85.2400457	total: 1.56s	remaining: 26.3s
# 56:	learn: 85.0992273	total: 1.58s	remaining: 26.2s
# 57:	learn: 84.9983161	total: 1.61s	remaining: 26.2s
# 58:	learn: 84.8648834	total: 1.63s	remaining: 26.1s
# 59:	learn: 84.7718360	total: 1.66s	remaining: 26s
# 60:	learn: 84.6287022	total: 1.68s	remaining: 25.9s
# 61:	learn: 84.5002613	total: 1.73s	remaining: 26.2s
# 62:	learn: 84.2970319	total: 1.77s	remaining: 26.3s
# 63:	learn: 84.1800221	total: 1.79s	remaining: 26.3s
# 64:	learn: 84.1400529	total: 1.83s	remaining: 26.3s
# 65:	learn: 84.0492290	total: 1.86s	remaining: 26.3s
# 66:	learn: 83.9383621	total: 1.88s	remaining: 26.2s
# 67:	learn: 83.8517583	total: 1.91s	remaining: 26.2s
# 68:	learn: 83.7713168	total: 1.93s	remaining: 26.1s
# 69:	learn: 83.6884656	total: 1.95s	remaining: 26s
# 70:	learn: 83.5365576	total: 1.98s	remaining: 25.9s
# 71:	learn: 83.4497247	total: 2s	remaining: 25.8s
# 72:	learn: 83.3608334	total: 2.02s	remaining: 25.7s
# 73:	learn: 83.2402857	total: 2.04s	remaining: 25.6s
# 74:	learn: 83.1695700	total: 2.06s	remaining: 25.5s
# 75:	learn: 83.0974654	total: 2.08s	remaining: 25.3s
# 76:	learn: 83.0345211	total: 2.11s	remaining: 25.3s
# 77:	learn: 82.9690433	total: 2.13s	remaining: 25.2s
# 78:	learn: 82.8601707	total: 2.15s	remaining: 25.1s
# 79:	learn: 82.7831934	total: 2.18s	remaining: 25s
# 80:	learn: 82.7240535	total: 2.2s	remaining: 25s
# 81:	learn: 82.6150693	total: 2.23s	remaining: 24.9s
# 82:	learn: 82.5557476	total: 2.25s	remaining: 24.8s
# 83:	learn: 82.4752377	total: 2.27s	remaining: 24.8s
# 84:	learn: 82.3925277	total: 2.29s	remaining: 24.7s
# 85:	learn: 82.2795451	total: 2.32s	remaining: 24.6s
# 86:	learn: 82.1664217	total: 2.34s	remaining: 24.5s
# 87:	learn: 82.0545139	total: 2.36s	remaining: 24.5s
# 88:	learn: 81.9797326	total: 2.38s	remaining: 24.4s
# 89:	learn: 81.8992536	total: 2.41s	remaining: 24.4s
# 90:	learn: 81.8404158	total: 2.43s	remaining: 24.3s
# 91:	learn: 81.7392631	total: 2.46s	remaining: 24.3s
# 92:	learn: 81.6469950	total: 2.48s	remaining: 24.2s
# 93:	learn: 81.5434302	total: 2.51s	remaining: 24.2s
# 94:	learn: 81.4224650	total: 2.53s	remaining: 24.1s
# 95:	learn: 81.3337108	total: 2.55s	remaining: 24s
# 96:	learn: 81.2114428	total: 2.58s	remaining: 24s
# 97:	learn: 81.1488499	total: 2.6s	remaining: 24s
# 98:	learn: 81.0607519	total: 2.63s	remaining: 23.9s
# 99:	learn: 80.9901126	total: 2.65s	remaining: 23.8s
# 100:	learn: 80.9407050	total: 2.67s	remaining: 23.7s
# 101:	learn: 80.8613812	total: 2.69s	remaining: 23.7s
# 102:	learn: 80.7702195	total: 2.71s	remaining: 23.6s
# 103:	learn: 80.6679766	total: 2.74s	remaining: 23.6s
# 104:	learn: 80.5882237	total: 2.76s	remaining: 23.5s
# 105:	learn: 80.5303811	total: 2.78s	remaining: 23.5s
# 106:	learn: 80.4501180	total: 2.81s	remaining: 23.4s
# 107:	learn: 80.3565126	total: 2.83s	remaining: 23.4s
# 108:	learn: 80.3102522	total: 2.87s	remaining: 23.4s
# 109:	learn: 80.1987698	total: 2.9s	remaining: 23.4s
# 110:	learn: 80.1292708	total: 2.93s	remaining: 23.5s
# 111:	learn: 80.0610389	total: 2.96s	remaining: 23.5s
# 112:	learn: 80.0206029	total: 2.99s	remaining: 23.4s
# 113:	learn: 79.9708339	total: 3.01s	remaining: 23.4s
# 114:	learn: 79.9092112	total: 3.03s	remaining: 23.3s
# 115:	learn: 79.8204523	total: 3.06s	remaining: 23.3s
# 116:	learn: 79.7516977	total: 3.08s	remaining: 23.3s
# 117:	learn: 79.6672736	total: 3.11s	remaining: 23.2s
# 118:	learn: 79.5874217	total: 3.13s	remaining: 23.2s
# 119:	learn: 79.5233464	total: 3.15s	remaining: 23.1s
# 120:	learn: 79.4616176	total: 3.17s	remaining: 23s
# 121:	learn: 79.3595332	total: 3.19s	remaining: 23s
# 122:	learn: 79.2490904	total: 3.22s	remaining: 23s
# 123:	learn: 79.1866039	total: 3.24s	remaining: 22.9s
# 124:	learn: 79.1569147	total: 3.26s	remaining: 22.8s
# 125:	learn: 79.0794436	total: 3.29s	remaining: 22.8s
# 126:	learn: 79.0147872	total: 3.31s	remaining: 22.7s
# 127:	learn: 78.9003911	total: 3.33s	remaining: 22.7s
# 128:	learn: 78.8100510	total: 3.36s	remaining: 22.7s
# 129:	learn: 78.7130142	total: 3.38s	remaining: 22.6s
# 130:	learn: 78.6626303	total: 3.4s	remaining: 22.6s
# 131:	learn: 78.6190101	total: 3.43s	remaining: 22.5s
# 132:	learn: 78.5290777	total: 3.45s	remaining: 22.5s
# 133:	learn: 78.4483510	total: 3.48s	remaining: 22.5s
# 134:	learn: 78.3992706	total: 3.5s	remaining: 22.4s
# 135:	learn: 78.3515743	total: 3.52s	remaining: 22.4s
# 136:	learn: 78.3073472	total: 3.54s	remaining: 22.3s
# 137:	learn: 78.2407178	total: 3.56s	remaining: 22.3s
# 138:	learn: 78.1999303	total: 3.58s	remaining: 22.2s
# 139:	learn: 78.1326044	total: 3.61s	remaining: 22.2s
# 140:	learn: 78.1277515	total: 3.63s	remaining: 22.1s
# 141:	learn: 78.0632865	total: 3.65s	remaining: 22.1s
# 142:	learn: 78.0019460	total: 3.68s	remaining: 22s
# 143:	learn: 77.9972453	total: 3.7s	remaining: 22s
# 144:	learn: 77.9371558	total: 3.72s	remaining: 21.9s
# 145:	learn: 77.8833619	total: 3.74s	remaining: 21.9s
# 146:	learn: 77.8266652	total: 3.76s	remaining: 21.8s
# 147:	learn: 77.8211380	total: 3.78s	remaining: 21.8s
# 148:	learn: 77.7578263	total: 3.81s	remaining: 21.7s
# 149:	learn: 77.6924614	total: 3.83s	remaining: 21.7s
# 150:	learn: 77.6219053	total: 3.85s	remaining: 21.7s
# 151:	learn: 77.5742219	total: 3.87s	remaining: 21.6s
# 152:	learn: 77.5281734	total: 3.9s	remaining: 21.6s
# 153:	learn: 77.4850364	total: 3.92s	remaining: 21.5s
# 154:	learn: 77.4207909	total: 3.94s	remaining: 21.5s
# 155:	learn: 77.3483190	total: 3.97s	remaining: 21.5s
# 156:	learn: 77.3224355	total: 4s	remaining: 21.5s
# 157:	learn: 77.2708882	total: 4.02s	remaining: 21.4s
# 158:	learn: 77.2160587	total: 4.04s	remaining: 21.4s
# 159:	learn: 77.0624493	total: 4.06s	remaining: 21.3s
# 160:	learn: 76.9860068	total: 4.09s	remaining: 21.3s
# 161:	learn: 76.9382766	total: 4.11s	remaining: 21.3s
# 162:	learn: 76.8511677	total: 4.13s	remaining: 21.2s
# 163:	learn: 76.7973366	total: 4.16s	remaining: 21.2s
# 164:	learn: 76.7502154	total: 4.18s	remaining: 21.1s
# 165:	learn: 76.7074530	total: 4.2s	remaining: 21.1s
# 166:	learn: 76.7026768	total: 4.22s	remaining: 21.1s
# 167:	learn: 76.6560457	total: 4.24s	remaining: 21s
# 168:	learn: 76.6517775	total: 4.26s	remaining: 21s
# 169:	learn: 76.6325833	total: 4.29s	remaining: 20.9s
# 170:	learn: 76.5988014	total: 4.31s	remaining: 20.9s
# 171:	learn: 76.5361125	total: 4.33s	remaining: 20.8s
# 172:	learn: 76.5321519	total: 4.35s	remaining: 20.8s
# 173:	learn: 76.5080879	total: 4.37s	remaining: 20.8s
# 174:	learn: 76.4190982	total: 4.4s	remaining: 20.7s
# 175:	learn: 76.3413081	total: 4.42s	remaining: 20.7s
# 176:	learn: 76.2791556	total: 4.44s	remaining: 20.7s
# 177:	learn: 76.2746307	total: 4.46s	remaining: 20.6s
# 178:	learn: 76.2306289	total: 4.48s	remaining: 20.6s
# 179:	learn: 76.1746455	total: 4.51s	remaining: 20.5s
# 180:	learn: 76.1496357	total: 4.53s	remaining: 20.5s
# 181:	learn: 76.0485433	total: 4.55s	remaining: 20.5s
# 182:	learn: 75.9862367	total: 4.58s	remaining: 20.4s
# 183:	learn: 75.9691986	total: 4.6s	remaining: 20.4s
# 184:	learn: 75.9091521	total: 4.62s	remaining: 20.4s
# 185:	learn: 75.8578438	total: 4.64s	remaining: 20.3s
# 186:	learn: 75.7796614	total: 4.67s	remaining: 20.3s
# 187:	learn: 75.7466431	total: 4.69s	remaining: 20.3s
# 188:	learn: 75.6841389	total: 4.71s	remaining: 20.2s
# 189:	learn: 75.6605852	total: 4.74s	remaining: 20.2s
# 190:	learn: 75.5962133	total: 4.76s	remaining: 20.2s
# 191:	learn: 75.5488566	total: 4.78s	remaining: 20.1s
# 192:	learn: 75.4833950	total: 4.8s	remaining: 20.1s
# 193:	learn: 75.4378378	total: 4.82s	remaining: 20s
# 194:	learn: 75.3963988	total: 4.84s	remaining: 20s
# 195:	learn: 75.3526345	total: 4.86s	remaining: 20s
# 196:	learn: 75.3061153	total: 4.89s	remaining: 20s
# 197:	learn: 75.2394945	total: 4.92s	remaining: 19.9s
# 198:	learn: 75.2038286	total: 4.94s	remaining: 19.9s
# 199:	learn: 75.1512650	total: 4.96s	remaining: 19.9s
# 200:	learn: 75.1309026	total: 4.99s	remaining: 19.8s
# 201:	learn: 75.0687524	total: 5.02s	remaining: 19.8s
# 202:	learn: 75.0026480	total: 5.04s	remaining: 19.8s
# 203:	learn: 74.9591365	total: 5.07s	remaining: 19.8s
# 204:	learn: 74.8754037	total: 5.11s	remaining: 19.8s
# 205:	learn: 74.8123653	total: 5.14s	remaining: 19.8s
# 206:	learn: 74.7670147	total: 5.17s	remaining: 19.8s
# 207:	learn: 74.7260102	total: 5.19s	remaining: 19.8s
# 208:	learn: 74.6870387	total: 5.22s	remaining: 19.8s
# 209:	learn: 74.6452345	total: 5.24s	remaining: 19.7s
# 210:	learn: 74.6064757	total: 5.26s	remaining: 19.7s
# 211:	learn: 74.5437810	total: 5.29s	remaining: 19.7s
# 212:	learn: 74.5062541	total: 5.31s	remaining: 19.6s
# 213:	learn: 74.4691993	total: 5.34s	remaining: 19.6s
# 214:	learn: 74.4426256	total: 5.36s	remaining: 19.6s
# 215:	learn: 74.4200174	total: 5.39s	remaining: 19.6s
# 216:	learn: 74.3638637	total: 5.41s	remaining: 19.5s
# 217:	learn: 74.3354444	total: 5.44s	remaining: 19.5s
# 218:	learn: 74.2749543	total: 5.46s	remaining: 19.5s
# 219:	learn: 74.1845786	total: 5.49s	remaining: 19.5s
# 220:	learn: 74.1180305	total: 5.52s	remaining: 19.4s
# 221:	learn: 74.0660650	total: 5.54s	remaining: 19.4s
# 222:	learn: 74.0454717	total: 5.57s	remaining: 19.4s
# 223:	learn: 73.9998550	total: 5.59s	remaining: 19.4s
# 224:	learn: 73.9631810	total: 5.62s	remaining: 19.3s
# 225:	learn: 73.9309460	total: 5.64s	remaining: 19.3s
# 226:	learn: 73.8979279	total: 5.67s	remaining: 19.3s
# 227:	learn: 73.8472542	total: 5.69s	remaining: 19.3s
# 228:	learn: 73.8158874	total: 5.71s	remaining: 19.2s
# 229:	learn: 73.7889749	total: 5.73s	remaining: 19.2s
# 230:	learn: 73.7413715	total: 5.76s	remaining: 19.2s
# 231:	learn: 73.7051645	total: 5.78s	remaining: 19.1s
# 232:	learn: 73.6416033	total: 5.81s	remaining: 19.1s
# 233:	learn: 73.6040733	total: 5.83s	remaining: 19.1s
# 234:	learn: 73.5481434	total: 5.87s	remaining: 19.1s
# 235:	learn: 73.4952596	total: 5.9s	remaining: 19.1s
# 236:	learn: 73.4436467	total: 5.94s	remaining: 19.1s
# 237:	learn: 73.3922584	total: 5.97s	remaining: 19.1s
# 238:	learn: 73.3389490	total: 6s	remaining: 19.1s
# 239:	learn: 73.3064971	total: 6.03s	remaining: 19.1s
# 240:	learn: 73.2582108	total: 6.06s	remaining: 19.1s
# 241:	learn: 73.2160633	total: 6.08s	remaining: 19.1s
# 242:	learn: 73.1803200	total: 6.11s	remaining: 19s
# 243:	learn: 73.1595215	total: 6.13s	remaining: 19s
# 244:	learn: 73.1217808	total: 6.15s	remaining: 18.9s
# 245:	learn: 73.0848103	total: 6.17s	remaining: 18.9s
# 246:	learn: 73.0119912	total: 6.2s	remaining: 18.9s
# 247:	learn: 72.9646444	total: 6.22s	remaining: 18.9s
# 248:	learn: 72.9173536	total: 6.24s	remaining: 18.8s
# 249:	learn: 72.8091445	total: 6.26s	remaining: 18.8s
# 250:	learn: 72.7516900	total: 6.29s	remaining: 18.8s
# 251:	learn: 72.7149676	total: 6.32s	remaining: 18.8s
# 252:	learn: 72.6640264	total: 6.35s	remaining: 18.8s
# 253:	learn: 72.6035363	total: 6.38s	remaining: 18.8s
# 254:	learn: 72.5436565	total: 6.41s	remaining: 18.7s
# 255:	learn: 72.5011078	total: 6.43s	remaining: 18.7s
# 256:	learn: 72.4728800	total: 6.46s	remaining: 18.7s
# 257:	learn: 72.4432169	total: 6.48s	remaining: 18.6s
# 258:	learn: 72.3800368	total: 6.5s	remaining: 18.6s
# 259:	learn: 72.3431091	total: 6.53s	remaining: 18.6s
# 260:	learn: 72.2960795	total: 6.55s	remaining: 18.5s
# 261:	learn: 72.2524639	total: 6.57s	remaining: 18.5s
# 262:	learn: 72.2107169	total: 6.59s	remaining: 18.5s
# 263:	learn: 72.1726255	total: 6.62s	remaining: 18.4s
# 264:	learn: 72.1429122	total: 6.64s	remaining: 18.4s
# 265:	learn: 72.1168786	total: 6.66s	remaining: 18.4s
# 266:	learn: 72.0821297	total: 6.69s	remaining: 18.4s
# 267:	learn: 72.0173947	total: 6.72s	remaining: 18.4s
# 268:	learn: 71.9898393	total: 6.75s	remaining: 18.3s
# 269:	learn: 71.9795664	total: 6.78s	remaining: 18.3s
# 270:	learn: 71.9220091	total: 6.81s	remaining: 18.3s
# 271:	learn: 71.8926749	total: 6.83s	remaining: 18.3s
# 272:	learn: 71.8703134	total: 6.85s	remaining: 18.3s
# 273:	learn: 71.8403630	total: 6.88s	remaining: 18.2s
# 274:	learn: 71.8107051	total: 6.91s	remaining: 18.2s
# 275:	learn: 71.7480783	total: 6.94s	remaining: 18.2s
# 276:	learn: 71.6645903	total: 6.97s	remaining: 18.2s
# 277:	learn: 71.6306525	total: 7s	remaining: 18.2s
# 278:	learn: 71.5916115	total: 7.02s	remaining: 18.1s
# 279:	learn: 71.5587757	total: 7.04s	remaining: 18.1s
# 280:	learn: 71.5166015	total: 7.06s	remaining: 18.1s
# 281:	learn: 71.4870322	total: 7.09s	remaining: 18s
# 282:	learn: 71.4598378	total: 7.11s	remaining: 18s
# 283:	learn: 71.4100616	total: 7.13s	remaining: 18s
# 284:	learn: 71.3397498	total: 7.16s	remaining: 18s
# 285:	learn: 71.2449290	total: 7.18s	remaining: 17.9s
# 286:	learn: 71.1932466	total: 7.21s	remaining: 17.9s
# 287:	learn: 71.1513808	total: 7.24s	remaining: 17.9s
# 288:	learn: 71.1057024	total: 7.26s	remaining: 17.9s
# 289:	learn: 71.0731586	total: 7.28s	remaining: 17.8s
# 290:	learn: 71.0277118	total: 7.3s	remaining: 17.8s
# 291:	learn: 70.9760846	total: 7.33s	remaining: 17.8s
# 292:	learn: 70.9608168	total: 7.35s	remaining: 17.7s
# 293:	learn: 70.9017798	total: 7.37s	remaining: 17.7s
# 294:	learn: 70.8472596	total: 7.39s	remaining: 17.7s
# 295:	learn: 70.7778827	total: 7.42s	remaining: 17.6s
# 296:	learn: 70.7467290	total: 7.44s	remaining: 17.6s
# 297:	learn: 70.7194584	total: 7.46s	remaining: 17.6s
# 298:	learn: 70.6823128	total: 7.49s	remaining: 17.6s
# 299:	learn: 70.6454419	total: 7.53s	remaining: 17.6s
# 300:	learn: 70.5966307	total: 7.56s	remaining: 17.6s
# 301:	learn: 70.5657687	total: 7.6s	remaining: 17.6s
# 302:	learn: 70.5411601	total: 7.62s	remaining: 17.5s
# 303:	learn: 70.4911519	total: 7.65s	remaining: 17.5s
# 304:	learn: 70.4625489	total: 7.68s	remaining: 17.5s
# 305:	learn: 70.4194257	total: 7.71s	remaining: 17.5s
# 306:	learn: 70.3481044	total: 7.74s	remaining: 17.5s
# 307:	learn: 70.3015969	total: 7.76s	remaining: 17.4s
# 308:	learn: 70.2709124	total: 7.78s	remaining: 17.4s
# 309:	learn: 70.2318817	total: 7.81s	remaining: 17.4s
# 310:	learn: 70.1997953	total: 7.83s	remaining: 17.3s
# 311:	learn: 70.1568816	total: 7.86s	remaining: 17.3s
# 312:	learn: 70.1301508	total: 7.89s	remaining: 17.3s
# 313:	learn: 70.0603619	total: 7.92s	remaining: 17.3s
# 314:	learn: 70.0292455	total: 7.96s	remaining: 17.3s
# 315:	learn: 69.9998135	total: 7.99s	remaining: 17.3s
# 316:	learn: 69.9543683	total: 8.01s	remaining: 17.3s
# 317:	learn: 69.9263357	total: 8.04s	remaining: 17.2s
# 318:	learn: 69.9005396	total: 8.06s	remaining: 17.2s
# 319:	learn: 69.8413029	total: 8.09s	remaining: 17.2s
# 320:	learn: 69.8112694	total: 8.11s	remaining: 17.2s
# 321:	learn: 69.7510079	total: 8.14s	remaining: 17.1s
# 322:	learn: 69.7115603	total: 8.17s	remaining: 17.1s
# 323:	learn: 69.6770988	total: 8.19s	remaining: 17.1s
# 324:	learn: 69.6487865	total: 8.21s	remaining: 17.1s
# 325:	learn: 69.6300046	total: 8.24s	remaining: 17s
# 326:	learn: 69.6107439	total: 8.27s	remaining: 17s
# 327:	learn: 69.5698282	total: 8.32s	remaining: 17.1s
# 328:	learn: 69.5568285	total: 8.36s	remaining: 17s
# 329:	learn: 69.5265983	total: 8.38s	remaining: 17s
# 330:	learn: 69.5089609	total: 8.4s	remaining: 17s
# 331:	learn: 69.4912918	total: 8.43s	remaining: 17s
# 332:	learn: 69.4577029	total: 8.45s	remaining: 16.9s
# 333:	learn: 69.4340242	total: 8.48s	remaining: 16.9s
# 334:	learn: 69.3736540	total: 8.51s	remaining: 16.9s
# 335:	learn: 69.3525066	total: 8.54s	remaining: 16.9s
# 336:	learn: 69.3286857	total: 8.57s	remaining: 16.9s
# 337:	learn: 69.2983245	total: 8.59s	remaining: 16.8s
# 338:	learn: 69.2702349	total: 8.61s	remaining: 16.8s
# 339:	learn: 69.2465452	total: 8.63s	remaining: 16.8s
# 340:	learn: 69.1927847	total: 8.66s	remaining: 16.7s
# 341:	learn: 69.1643402	total: 8.68s	remaining: 16.7s
# 342:	learn: 69.1294588	total: 8.71s	remaining: 16.7s
# 343:	learn: 69.0788789	total: 8.74s	remaining: 16.7s
# 344:	learn: 69.0283888	total: 8.77s	remaining: 16.6s
# 345:	learn: 68.9852096	total: 8.8s	remaining: 16.6s
# 346:	learn: 68.9633817	total: 8.83s	remaining: 16.6s
# 347:	learn: 68.9373171	total: 8.86s	remaining: 16.6s
# 348:	learn: 68.9103766	total: 8.88s	remaining: 16.6s
# 349:	learn: 68.8880082	total: 8.91s	remaining: 16.5s
# 350:	learn: 68.8680366	total: 8.93s	remaining: 16.5s
# 351:	learn: 68.8248855	total: 8.96s	remaining: 16.5s
# 352:	learn: 68.8227489	total: 8.98s	remaining: 16.5s
# 353:	learn: 68.7964659	total: 9s	remaining: 16.4s
# 354:	learn: 68.7541033	total: 9.02s	remaining: 16.4s
# 355:	learn: 68.7371170	total: 9.04s	remaining: 16.4s
# 356:	learn: 68.6952965	total: 9.06s	remaining: 16.3s
# 357:	learn: 68.6786741	total: 9.08s	remaining: 16.3s
# 358:	learn: 68.6572220	total: 9.1s	remaining: 16.3s
# 359:	learn: 68.6032093	total: 9.13s	remaining: 16.2s
# 360:	learn: 68.5602803	total: 9.16s	remaining: 16.2s
# 361:	learn: 68.5254537	total: 9.19s	remaining: 16.2s
# 362:	learn: 68.5024706	total: 9.21s	remaining: 16.2s
# 363:	learn: 68.4428641	total: 9.23s	remaining: 16.1s
# 364:	learn: 68.4131934	total: 9.26s	remaining: 16.1s
# 365:	learn: 68.3854976	total: 9.28s	remaining: 16.1s
# 366:	learn: 68.3466503	total: 9.3s	remaining: 16s
# 367:	learn: 68.3280215	total: 9.32s	remaining: 16s
# 368:	learn: 68.3254523	total: 9.34s	remaining: 16s
# 369:	learn: 68.2941675	total: 9.36s	remaining: 15.9s
# 370:	learn: 68.2668922	total: 9.38s	remaining: 15.9s
# 371:	learn: 68.2263780	total: 9.41s	remaining: 15.9s
# 372:	learn: 68.2144067	total: 9.43s	remaining: 15.9s
# 373:	learn: 68.1475352	total: 9.46s	remaining: 15.8s
# 374:	learn: 68.1362484	total: 9.48s	remaining: 15.8s
# 375:	learn: 68.1256062	total: 9.5s	remaining: 15.8s
# 376:	learn: 68.0999717	total: 9.52s	remaining: 15.7s
# 377:	learn: 68.0874219	total: 9.54s	remaining: 15.7s
# 378:	learn: 68.0639781	total: 9.56s	remaining: 15.7s
# 379:	learn: 68.0184558	total: 9.58s	remaining: 15.6s
# 380:	learn: 68.0115842	total: 9.6s	remaining: 15.6s
# 381:	learn: 67.9947781	total: 9.62s	remaining: 15.6s
# 382:	learn: 67.9561193	total: 9.64s	remaining: 15.5s
# 383:	learn: 67.9358916	total: 9.67s	remaining: 15.5s
# 384:	learn: 67.9054287	total: 9.7s	remaining: 15.5s
# 385:	learn: 67.8594187	total: 9.72s	remaining: 15.5s
# 386:	learn: 67.8432328	total: 9.75s	remaining: 15.4s
# 387:	learn: 67.7908269	total: 9.78s	remaining: 15.4s
# 388:	learn: 67.7663173	total: 9.8s	remaining: 15.4s
# 389:	learn: 67.7355745	total: 9.83s	remaining: 15.4s
# 390:	learn: 67.7045007	total: 9.85s	remaining: 15.3s
# 391:	learn: 67.6499134	total: 9.88s	remaining: 15.3s
# 392:	learn: 67.6338558	total: 9.9s	remaining: 15.3s
# 393:	learn: 67.6037424	total: 9.93s	remaining: 15.3s
# 394:	learn: 67.5759658	total: 9.95s	remaining: 15.2s
# 395:	learn: 67.5520320	total: 9.97s	remaining: 15.2s
# 396:	learn: 67.5306430	total: 9.99s	remaining: 15.2s
# 397:	learn: 67.5105381	total: 10s	remaining: 15.1s
# 398:	learn: 67.4801672	total: 10s	remaining: 15.1s
# 399:	learn: 67.4528369	total: 10.1s	remaining: 15.1s
# 400:	learn: 67.3636935	total: 10.1s	remaining: 15.1s
# 401:	learn: 67.3283663	total: 10.1s	remaining: 15s
# 402:	learn: 67.2923767	total: 10.1s	remaining: 15s
# 403:	learn: 67.2737951	total: 10.2s	remaining: 15s
# 404:	learn: 67.2645523	total: 10.2s	remaining: 15s
# 405:	learn: 67.2441612	total: 10.2s	remaining: 14.9s
# 406:	learn: 67.2423500	total: 10.2s	remaining: 14.9s
# 407:	learn: 67.2058324	total: 10.2s	remaining: 14.9s
# 408:	learn: 67.1785098	total: 10.3s	remaining: 14.8s
# 409:	learn: 67.1482404	total: 10.3s	remaining: 14.8s
# 410:	learn: 67.1150197	total: 10.3s	remaining: 14.8s
# 411:	learn: 67.1091639	total: 10.3s	remaining: 14.8s
# 412:	learn: 67.0948095	total: 10.4s	remaining: 14.7s
# 413:	learn: 67.0467122	total: 10.4s	remaining: 14.7s
# 414:	learn: 67.0234303	total: 10.4s	remaining: 14.7s
# 415:	learn: 67.0070164	total: 10.5s	remaining: 14.7s
# 416:	learn: 66.9933381	total: 10.5s	remaining: 14.6s
# 417:	learn: 66.9524802	total: 10.5s	remaining: 14.6s
# 418:	learn: 66.9275459	total: 10.5s	remaining: 14.6s
# 419:	learn: 66.9004840	total: 10.5s	remaining: 14.6s
# 420:	learn: 66.8554292	total: 10.6s	remaining: 14.5s
# 421:	learn: 66.8391638	total: 10.6s	remaining: 14.5s
# 422:	learn: 66.8180099	total: 10.6s	remaining: 14.5s
# 423:	learn: 66.7973319	total: 10.6s	remaining: 14.4s
# 424:	learn: 66.7726798	total: 10.6s	remaining: 14.4s
# 425:	learn: 66.7258538	total: 10.7s	remaining: 14.4s
# 426:	learn: 66.7028819	total: 10.7s	remaining: 14.3s
# 427:	learn: 66.6731978	total: 10.7s	remaining: 14.3s
# 428:	learn: 66.6355977	total: 10.7s	remaining: 14.3s
# 429:	learn: 66.6062544	total: 10.7s	remaining: 14.2s
# 430:	learn: 66.5953632	total: 10.8s	remaining: 14.2s
# 431:	learn: 66.5803658	total: 10.8s	remaining: 14.2s
# 432:	learn: 66.5524032	total: 10.8s	remaining: 14.2s
# 433:	learn: 66.5331433	total: 10.8s	remaining: 14.1s
# 434:	learn: 66.5025891	total: 10.9s	remaining: 14.1s
# 435:	learn: 66.4748860	total: 10.9s	remaining: 14.1s
# 436:	learn: 66.4359625	total: 10.9s	remaining: 14.1s
# 437:	learn: 66.4149113	total: 10.9s	remaining: 14s
# 438:	learn: 66.3956742	total: 11s	remaining: 14s
# 439:	learn: 66.3566640	total: 11s	remaining: 14s
# 440:	learn: 66.3282072	total: 11s	remaining: 14s
# 441:	learn: 66.2912937	total: 11s	remaining: 13.9s
# 442:	learn: 66.2764063	total: 11.1s	remaining: 13.9s
# 443:	learn: 66.2084223	total: 11.1s	remaining: 13.9s
# 444:	learn: 66.1633180	total: 11.1s	remaining: 13.8s
# 445:	learn: 66.1375780	total: 11.1s	remaining: 13.8s
# 446:	learn: 66.0953972	total: 11.1s	remaining: 13.8s
# 447:	learn: 66.0646561	total: 11.2s	remaining: 13.8s
# 448:	learn: 66.0397373	total: 11.2s	remaining: 13.8s
# 449:	learn: 66.0310840	total: 11.3s	remaining: 13.8s
# 450:	learn: 66.0291269	total: 11.3s	remaining: 13.7s
# 451:	learn: 66.0269882	total: 11.3s	remaining: 13.7s
# 452:	learn: 66.0084765	total: 11.3s	remaining: 13.7s
# 453:	learn: 65.9605502	total: 11.4s	remaining: 13.7s
# 454:	learn: 65.9283599	total: 11.4s	remaining: 13.7s
# 455:	learn: 65.9047459	total: 11.4s	remaining: 13.6s
# 456:	learn: 65.8557241	total: 11.5s	remaining: 13.6s
# 457:	learn: 65.8374297	total: 11.5s	remaining: 13.6s
# 458:	learn: 65.8228515	total: 11.5s	remaining: 13.6s
# 459:	learn: 65.7955828	total: 11.5s	remaining: 13.6s
# 460:	learn: 65.7913370	total: 11.6s	remaining: 13.5s
# 461:	learn: 65.7719328	total: 11.6s	remaining: 13.5s
# 462:	learn: 65.7403553	total: 11.6s	remaining: 13.5s
# 463:	learn: 65.7010062	total: 11.6s	remaining: 13.4s
# 464:	learn: 65.6828067	total: 11.7s	remaining: 13.4s
# 465:	learn: 65.6475622	total: 11.7s	remaining: 13.4s
# 466:	learn: 65.6118124	total: 11.7s	remaining: 13.4s
# 467:	learn: 65.5815209	total: 11.7s	remaining: 13.3s
# 468:	learn: 65.5104070	total: 11.8s	remaining: 13.3s
# 469:	learn: 65.4941352	total: 11.8s	remaining: 13.3s
# 470:	learn: 65.4708150	total: 11.8s	remaining: 13.3s
# 471:	learn: 65.4495940	total: 11.8s	remaining: 13.2s
# 472:	learn: 65.4481280	total: 11.8s	remaining: 13.2s
# 473:	learn: 65.4462918	total: 11.9s	remaining: 13.2s
# 474:	learn: 65.4240473	total: 11.9s	remaining: 13.1s
# 475:	learn: 65.3703568	total: 11.9s	remaining: 13.1s
# 476:	learn: 65.3670148	total: 11.9s	remaining: 13.1s
# 477:	learn: 65.3483453	total: 12s	remaining: 13.1s
# 478:	learn: 65.3470120	total: 12s	remaining: 13s
# 479:	learn: 65.3454152	total: 12s	remaining: 13s
# 480:	learn: 65.3243607	total: 12s	remaining: 13s
# 481:	learn: 65.2816547	total: 12.1s	remaining: 12.9s
# 482:	learn: 65.2646791	total: 12.1s	remaining: 12.9s
# 483:	learn: 65.2296569	total: 12.1s	remaining: 12.9s
# 484:	learn: 65.2123516	total: 12.1s	remaining: 12.9s
# 485:	learn: 65.1846791	total: 12.2s	remaining: 12.9s
# 486:	learn: 65.1510981	total: 12.2s	remaining: 12.8s
# 487:	learn: 65.1233113	total: 12.2s	remaining: 12.8s
# 488:	learn: 65.0866427	total: 12.2s	remaining: 12.8s
# 489:	learn: 65.0854618	total: 12.2s	remaining: 12.7s
# 490:	learn: 65.0596346	total: 12.3s	remaining: 12.7s
# 491:	learn: 65.0328518	total: 12.3s	remaining: 12.7s
# 492:	learn: 65.0100138	total: 12.3s	remaining: 12.7s
# 493:	learn: 64.9887745	total: 12.3s	remaining: 12.6s
# 494:	learn: 64.9754913	total: 12.3s	remaining: 12.6s
# 495:	learn: 64.9196042	total: 12.4s	remaining: 12.6s
# 496:	learn: 64.9182603	total: 12.4s	remaining: 12.5s
# 497:	learn: 64.8753576	total: 12.4s	remaining: 12.5s
# 498:	learn: 64.8514948	total: 12.4s	remaining: 12.5s
# 499:	learn: 64.8273327	total: 12.5s	remaining: 12.5s
# 500:	learn: 64.7926332	total: 12.5s	remaining: 12.4s
# 501:	learn: 64.7549640	total: 12.5s	remaining: 12.4s
# 502:	learn: 64.7154539	total: 12.5s	remaining: 12.4s
# 503:	learn: 64.6704669	total: 12.5s	remaining: 12.3s
# 504:	learn: 64.6500488	total: 12.6s	remaining: 12.3s
# 505:	learn: 64.6138384	total: 12.6s	remaining: 12.3s
# 506:	learn: 64.5907938	total: 12.6s	remaining: 12.3s
# 507:	learn: 64.5524601	total: 12.6s	remaining: 12.2s
# 508:	learn: 64.5137962	total: 12.7s	remaining: 12.2s
# 509:	learn: 64.5003544	total: 12.7s	remaining: 12.2s
# 510:	learn: 64.4852378	total: 12.7s	remaining: 12.2s
# 511:	learn: 64.4243656	total: 12.7s	remaining: 12.1s
# 512:	learn: 64.4075518	total: 12.8s	remaining: 12.1s
# 513:	learn: 64.3421611	total: 12.8s	remaining: 12.1s
# 514:	learn: 64.3413527	total: 12.8s	remaining: 12s
# 515:	learn: 64.3159293	total: 12.8s	remaining: 12s
# 516:	learn: 64.2996766	total: 12.8s	remaining: 12s
# 517:	learn: 64.2718912	total: 12.9s	remaining: 12s
# 518:	learn: 64.2590358	total: 12.9s	remaining: 11.9s
# 519:	learn: 64.2297783	total: 12.9s	remaining: 11.9s
# 520:	learn: 64.2112311	total: 12.9s	remaining: 11.9s
# 521:	learn: 64.1656524	total: 13s	remaining: 11.9s
# 522:	learn: 64.1413454	total: 13s	remaining: 11.8s
# 523:	learn: 64.1294673	total: 13s	remaining: 11.8s
# 524:	learn: 64.1045096	total: 13s	remaining: 11.8s
# 525:	learn: 64.0730862	total: 13.1s	remaining: 11.8s
# 526:	learn: 64.0541358	total: 13.1s	remaining: 11.7s
# 527:	learn: 64.0321285	total: 13.1s	remaining: 11.7s
# 528:	learn: 64.0024165	total: 13.1s	remaining: 11.7s
# 529:	learn: 63.9944994	total: 13.2s	remaining: 11.7s
# 530:	learn: 63.9683801	total: 13.2s	remaining: 11.6s
# 531:	learn: 63.9425278	total: 13.2s	remaining: 11.6s
# 532:	learn: 63.9320594	total: 13.2s	remaining: 11.6s
# 533:	learn: 63.9002193	total: 13.2s	remaining: 11.6s
# 534:	learn: 63.8604462	total: 13.3s	remaining: 11.5s
# 535:	learn: 63.8299883	total: 13.3s	remaining: 11.5s
# 536:	learn: 63.8071265	total: 13.3s	remaining: 11.5s
# 537:	learn: 63.7794120	total: 13.3s	remaining: 11.5s
# 538:	learn: 63.7413851	total: 13.4s	remaining: 11.4s
# 539:	learn: 63.7302043	total: 13.4s	remaining: 11.4s
# 540:	learn: 63.7195575	total: 13.4s	remaining: 11.4s
# 541:	learn: 63.7054646	total: 13.4s	remaining: 11.3s
# 542:	learn: 63.6830030	total: 13.4s	remaining: 11.3s
# 543:	learn: 63.6671959	total: 13.5s	remaining: 11.3s
# 544:	learn: 63.6439496	total: 13.5s	remaining: 11.3s
# 545:	learn: 63.6179617	total: 13.5s	remaining: 11.2s
# 546:	learn: 63.5835397	total: 13.5s	remaining: 11.2s
# 547:	learn: 63.5757343	total: 13.6s	remaining: 11.2s
# 548:	learn: 63.5608010	total: 13.6s	remaining: 11.2s
# 549:	learn: 63.5433317	total: 13.6s	remaining: 11.1s
# 550:	learn: 63.5293550	total: 13.6s	remaining: 11.1s
# 551:	learn: 63.5036880	total: 13.6s	remaining: 11.1s
# 552:	learn: 63.4914416	total: 13.7s	remaining: 11s
# 553:	learn: 63.4720059	total: 13.7s	remaining: 11s
# 554:	learn: 63.4431800	total: 13.7s	remaining: 11s
# 555:	learn: 63.4246904	total: 13.7s	remaining: 11s
# 556:	learn: 63.3828133	total: 13.7s	remaining: 10.9s
# 557:	learn: 63.3319494	total: 13.8s	remaining: 10.9s
# 558:	learn: 63.3183881	total: 13.8s	remaining: 10.9s
# 559:	learn: 63.2948791	total: 13.8s	remaining: 10.9s
# 560:	learn: 63.2723057	total: 13.8s	remaining: 10.8s
# 561:	learn: 63.2441309	total: 13.9s	remaining: 10.8s
# 562:	learn: 63.2266668	total: 13.9s	remaining: 10.8s
# 563:	learn: 63.2042858	total: 13.9s	remaining: 10.8s
# 564:	learn: 63.1789475	total: 14s	remaining: 10.8s
# 565:	learn: 63.1595014	total: 14s	remaining: 10.7s
# 566:	learn: 63.1223172	total: 14.1s	remaining: 10.7s
# 567:	learn: 63.1022688	total: 14.1s	remaining: 10.7s
# 568:	learn: 63.0904279	total: 14.1s	remaining: 10.7s
# 569:	learn: 63.0744661	total: 14.2s	remaining: 10.7s
# 570:	learn: 63.0545328	total: 14.2s	remaining: 10.7s
# 571:	learn: 63.0251641	total: 14.2s	remaining: 10.6s
# 572:	learn: 63.0178423	total: 14.2s	remaining: 10.6s
# 573:	learn: 62.9941021	total: 14.3s	remaining: 10.6s
# 574:	learn: 62.9677720	total: 14.3s	remaining: 10.6s
# 575:	learn: 62.9470857	total: 14.3s	remaining: 10.5s
# 576:	learn: 62.9052321	total: 14.4s	remaining: 10.5s
# 577:	learn: 62.9031774	total: 14.4s	remaining: 10.5s
# 578:	learn: 62.8898522	total: 14.4s	remaining: 10.5s
# 579:	learn: 62.8534349	total: 14.4s	remaining: 10.5s
# 580:	learn: 62.8381681	total: 14.5s	remaining: 10.4s
# 581:	learn: 62.7916184	total: 14.5s	remaining: 10.4s
# 582:	learn: 62.7764216	total: 14.5s	remaining: 10.4s
# 583:	learn: 62.7685076	total: 14.5s	remaining: 10.4s
# 584:	learn: 62.7558773	total: 14.6s	remaining: 10.3s
# 585:	learn: 62.7351290	total: 14.6s	remaining: 10.3s
# 586:	learn: 62.7112279	total: 14.6s	remaining: 10.3s
# 587:	learn: 62.6851124	total: 14.6s	remaining: 10.3s
# 588:	learn: 62.6500446	total: 14.7s	remaining: 10.2s
# 589:	learn: 62.6197634	total: 14.7s	remaining: 10.2s
# 590:	learn: 62.6097278	total: 14.7s	remaining: 10.2s
# 591:	learn: 62.5613615	total: 14.7s	remaining: 10.2s
# 592:	learn: 62.5542040	total: 14.8s	remaining: 10.1s
# 593:	learn: 62.5241138	total: 14.8s	remaining: 10.1s
# 594:	learn: 62.4846403	total: 14.8s	remaining: 10.1s
# 595:	learn: 62.4420498	total: 14.8s	remaining: 10.1s
# 596:	learn: 62.4145584	total: 14.9s	remaining: 10s
# 597:	learn: 62.4090642	total: 14.9s	remaining: 10s
# 598:	learn: 62.3945878	total: 14.9s	remaining: 9.98s
# 599:	learn: 62.3579188	total: 14.9s	remaining: 9.95s
# 600:	learn: 62.3381747	total: 15s	remaining: 9.93s
# 601:	learn: 62.3096606	total: 15s	remaining: 9.9s
# 602:	learn: 62.2446667	total: 15s	remaining: 9.88s
# 603:	learn: 62.2158462	total: 15s	remaining: 9.86s
# 604:	learn: 62.2140829	total: 15.1s	remaining: 9.83s
# 605:	learn: 62.1929491	total: 15.1s	remaining: 9.8s
# 606:	learn: 62.1641370	total: 15.1s	remaining: 9.78s
# 607:	learn: 62.1495436	total: 15.1s	remaining: 9.76s
# 608:	learn: 62.1272632	total: 15.2s	remaining: 9.73s
# 609:	learn: 62.0988281	total: 15.2s	remaining: 9.71s
# 610:	learn: 62.0704929	total: 15.2s	remaining: 9.68s
# 611:	learn: 62.0520673	total: 15.2s	remaining: 9.65s
# 612:	learn: 62.0365591	total: 15.2s	remaining: 9.62s
# 613:	learn: 62.0177187	total: 15.3s	remaining: 9.6s
# 614:	learn: 61.9898101	total: 15.3s	remaining: 9.57s
# 615:	learn: 61.9741826	total: 15.3s	remaining: 9.54s
# 616:	learn: 61.9671815	total: 15.3s	remaining: 9.51s
# 617:	learn: 61.9433530	total: 15.3s	remaining: 9.48s
# 618:	learn: 61.9322531	total: 15.4s	remaining: 9.46s
# 619:	learn: 61.9231035	total: 15.4s	remaining: 9.43s
# 620:	learn: 61.9004006	total: 15.4s	remaining: 9.4s
# 621:	learn: 61.8829672	total: 15.4s	remaining: 9.37s
# 622:	learn: 61.8591488	total: 15.5s	remaining: 9.35s
# 623:	learn: 61.8262231	total: 15.5s	remaining: 9.33s
# 624:	learn: 61.8188560	total: 15.5s	remaining: 9.31s
# 625:	learn: 61.8160662	total: 15.5s	remaining: 9.28s
# 626:	learn: 61.7816759	total: 15.6s	remaining: 9.26s
# 627:	learn: 61.7617960	total: 15.6s	remaining: 9.23s
# 628:	learn: 61.7359471	total: 15.6s	remaining: 9.2s
# 629:	learn: 61.7266742	total: 15.6s	remaining: 9.17s
# 630:	learn: 61.7054787	total: 15.6s	remaining: 9.15s
# 631:	learn: 61.6633299	total: 15.7s	remaining: 9.12s
# 632:	learn: 61.6527515	total: 15.7s	remaining: 9.09s
# 633:	learn: 61.6331356	total: 15.7s	remaining: 9.07s
# 634:	learn: 61.6156322	total: 15.7s	remaining: 9.04s
# 635:	learn: 61.5956940	total: 15.7s	remaining: 9.01s
# 636:	learn: 61.5822772	total: 15.8s	remaining: 8.99s
# 637:	learn: 61.5690637	total: 15.8s	remaining: 8.96s
# 638:	learn: 61.5581083	total: 15.8s	remaining: 8.93s
# 639:	learn: 61.5438750	total: 15.8s	remaining: 8.9s
# 640:	learn: 61.5315827	total: 15.9s	remaining: 8.88s
# 641:	learn: 61.5169217	total: 15.9s	remaining: 8.85s
# 642:	learn: 61.4984435	total: 15.9s	remaining: 8.83s
# 643:	learn: 61.4734999	total: 15.9s	remaining: 8.8s
# 644:	learn: 61.4594198	total: 15.9s	remaining: 8.77s
# 645:	learn: 61.4324280	total: 16s	remaining: 8.74s
# 646:	learn: 61.4111540	total: 16s	remaining: 8.72s
# 647:	learn: 61.3731334	total: 16s	remaining: 8.69s
# 648:	learn: 61.3403251	total: 16s	remaining: 8.66s
# 649:	learn: 61.3251774	total: 16s	remaining: 8.64s
# 650:	learn: 61.3011773	total: 16.1s	remaining: 8.61s
# 651:	learn: 61.2829887	total: 16.1s	remaining: 8.59s
# 652:	learn: 61.2546805	total: 16.1s	remaining: 8.56s
# 653:	learn: 61.2280298	total: 16.1s	remaining: 8.53s
# 654:	learn: 61.2182570	total: 16.1s	remaining: 8.51s
# 655:	learn: 61.1945188	total: 16.2s	remaining: 8.48s
# 656:	learn: 61.1809199	total: 16.2s	remaining: 8.45s
# 657:	learn: 61.1563462	total: 16.2s	remaining: 8.43s
# 658:	learn: 61.1554470	total: 16.2s	remaining: 8.4s
# 659:	learn: 61.1216932	total: 16.3s	remaining: 8.37s
# 660:	learn: 61.0800097	total: 16.3s	remaining: 8.35s
# 661:	learn: 61.0482271	total: 16.3s	remaining: 8.32s
# 662:	learn: 61.0475255	total: 16.3s	remaining: 8.29s
# 663:	learn: 61.0356310	total: 16.3s	remaining: 8.27s
# 664:	learn: 61.0053442	total: 16.4s	remaining: 8.24s
# 665:	learn: 60.9628056	total: 16.4s	remaining: 8.21s
# 666:	learn: 60.9475080	total: 16.4s	remaining: 8.19s
# 667:	learn: 60.9365206	total: 16.4s	remaining: 8.16s
# 668:	learn: 60.9109440	total: 16.4s	remaining: 8.13s
# 669:	learn: 60.9033650	total: 16.5s	remaining: 8.11s
# 670:	learn: 60.8702091	total: 16.5s	remaining: 8.08s
# 671:	learn: 60.8493340	total: 16.5s	remaining: 8.05s
# 672:	learn: 60.8430604	total: 16.5s	remaining: 8.03s
# 673:	learn: 60.8238377	total: 16.5s	remaining: 8s
# 674:	learn: 60.7933469	total: 16.6s	remaining: 7.97s
# 675:	learn: 60.7675187	total: 16.6s	remaining: 7.95s
# 676:	learn: 60.7540998	total: 16.6s	remaining: 7.92s
# 677:	learn: 60.7312158	total: 16.6s	remaining: 7.89s
# 678:	learn: 60.6889785	total: 16.6s	remaining: 7.87s
# 679:	learn: 60.6815226	total: 16.7s	remaining: 7.84s
# 680:	learn: 60.6420665	total: 16.7s	remaining: 7.82s
# 681:	learn: 60.6099949	total: 16.7s	remaining: 7.79s
# 682:	learn: 60.6093485	total: 16.7s	remaining: 7.76s
# 683:	learn: 60.5828708	total: 16.7s	remaining: 7.74s
# 684:	learn: 60.5706095	total: 16.8s	remaining: 7.71s
# 685:	learn: 60.5567882	total: 16.8s	remaining: 7.68s
# 686:	learn: 60.5287441	total: 16.8s	remaining: 7.66s
# 687:	learn: 60.4813412	total: 16.8s	remaining: 7.63s
# 688:	learn: 60.4765342	total: 16.9s	remaining: 7.61s
# 689:	learn: 60.4546467	total: 16.9s	remaining: 7.58s
# 690:	learn: 60.4268522	total: 16.9s	remaining: 7.55s
# 691:	learn: 60.4147933	total: 16.9s	remaining: 7.53s
# 692:	learn: 60.3990414	total: 16.9s	remaining: 7.5s
# 693:	learn: 60.3914629	total: 17s	remaining: 7.47s
# 694:	learn: 60.3714718	total: 17s	remaining: 7.45s
# 695:	learn: 60.3603435	total: 17s	remaining: 7.42s
# 696:	learn: 60.3530197	total: 17s	remaining: 7.4s
# 697:	learn: 60.3172970	total: 17s	remaining: 7.37s
# 698:	learn: 60.3021447	total: 17.1s	remaining: 7.34s
# 699:	learn: 60.2903163	total: 17.1s	remaining: 7.32s
# 700:	learn: 60.2642454	total: 17.1s	remaining: 7.29s
# 701:	learn: 60.2483426	total: 17.1s	remaining: 7.27s
# 702:	learn: 60.2351242	total: 17.1s	remaining: 7.24s
# 703:	learn: 60.2211146	total: 17.2s	remaining: 7.22s
# 704:	learn: 60.2027556	total: 17.2s	remaining: 7.19s
# 705:	learn: 60.1608520	total: 17.2s	remaining: 7.17s
# 706:	learn: 60.1454729	total: 17.2s	remaining: 7.14s
# 707:	learn: 60.1249552	total: 17.3s	remaining: 7.11s
# 708:	learn: 60.1075831	total: 17.3s	remaining: 7.09s
# 709:	learn: 60.0816237	total: 17.3s	remaining: 7.06s
# 710:	learn: 60.0623347	total: 17.3s	remaining: 7.04s
# 711:	learn: 60.0440859	total: 17.3s	remaining: 7.01s
# 712:	learn: 60.0189096	total: 17.4s	remaining: 6.99s
# 713:	learn: 59.9656413	total: 17.4s	remaining: 6.96s
# 714:	learn: 59.9486721	total: 17.4s	remaining: 6.93s
# 715:	learn: 59.9317588	total: 17.4s	remaining: 6.91s
# 716:	learn: 59.9176544	total: 17.5s	remaining: 6.89s
# 717:	learn: 59.9108200	total: 17.5s	remaining: 6.87s
# 718:	learn: 59.8882956	total: 17.5s	remaining: 6.84s
# 719:	learn: 59.8775112	total: 17.5s	remaining: 6.82s
# 720:	learn: 59.8606782	total: 17.6s	remaining: 6.8s
# 721:	learn: 59.8328617	total: 17.6s	remaining: 6.78s
# 722:	learn: 59.8086443	total: 17.6s	remaining: 6.75s
# 723:	learn: 59.7884460	total: 17.7s	remaining: 6.73s
# 724:	learn: 59.7867897	total: 17.7s	remaining: 6.71s
# 725:	learn: 59.7647600	total: 17.7s	remaining: 6.68s
# 726:	learn: 59.7535455	total: 17.7s	remaining: 6.66s
# 727:	learn: 59.7303731	total: 17.8s	remaining: 6.63s
# 728:	learn: 59.7129775	total: 17.8s	remaining: 6.61s
# 729:	learn: 59.6860871	total: 17.8s	remaining: 6.58s
# 730:	learn: 59.6854174	total: 17.8s	remaining: 6.56s
# 731:	learn: 59.6681617	total: 17.8s	remaining: 6.53s
# 732:	learn: 59.6421886	total: 17.9s	remaining: 6.51s
# 733:	learn: 59.6305212	total: 17.9s	remaining: 6.48s
# 734:	learn: 59.6148800	total: 17.9s	remaining: 6.46s
# 735:	learn: 59.6034255	total: 17.9s	remaining: 6.43s
# 736:	learn: 59.5954150	total: 18s	remaining: 6.41s
# 737:	learn: 59.5855691	total: 18s	remaining: 6.38s
# 738:	learn: 59.5559458	total: 18s	remaining: 6.36s
# 739:	learn: 59.5335860	total: 18s	remaining: 6.33s
# 740:	learn: 59.5174767	total: 18.1s	remaining: 6.31s
# 741:	learn: 59.5117445	total: 18.1s	remaining: 6.29s
# 742:	learn: 59.4814569	total: 18.1s	remaining: 6.26s
# 743:	learn: 59.4612169	total: 18.1s	remaining: 6.23s
# 744:	learn: 59.4470575	total: 18.1s	remaining: 6.21s
# 745:	learn: 59.4209497	total: 18.2s	remaining: 6.18s
# 746:	learn: 59.3829760	total: 18.2s	remaining: 6.16s
# 747:	learn: 59.3739524	total: 18.2s	remaining: 6.13s
# 748:	learn: 59.3424661	total: 18.2s	remaining: 6.11s
# 749:	learn: 59.3190880	total: 18.3s	remaining: 6.09s
# 750:	learn: 59.3073123	total: 18.3s	remaining: 6.06s
# 751:	learn: 59.2700376	total: 18.3s	remaining: 6.04s
# 752:	learn: 59.2536132	total: 18.3s	remaining: 6.01s
# 753:	learn: 59.2448866	total: 18.4s	remaining: 5.99s
# 754:	learn: 59.2145623	total: 18.4s	remaining: 5.97s
# 755:	learn: 59.1910128	total: 18.4s	remaining: 5.94s
# 756:	learn: 59.1826051	total: 18.4s	remaining: 5.92s
# 757:	learn: 59.1560156	total: 18.5s	remaining: 5.89s
# 758:	learn: 59.1478093	total: 18.5s	remaining: 5.87s
# 759:	learn: 59.1398443	total: 18.5s	remaining: 5.84s
# 760:	learn: 59.1184221	total: 18.5s	remaining: 5.82s
# 761:	learn: 59.1038269	total: 18.6s	remaining: 5.79s
# 762:	learn: 59.0943566	total: 18.6s	remaining: 5.77s
# 763:	learn: 59.0740402	total: 18.6s	remaining: 5.74s
# 764:	learn: 59.0676102	total: 18.6s	remaining: 5.72s
# 765:	learn: 59.0533450	total: 18.6s	remaining: 5.69s
# 766:	learn: 59.0387773	total: 18.6s	remaining: 5.67s
# 767:	learn: 59.0370318	total: 18.7s	remaining: 5.64s
# 768:	learn: 59.0244590	total: 18.7s	remaining: 5.61s
# 769:	learn: 59.0203812	total: 18.7s	remaining: 5.59s
# 770:	learn: 58.9923620	total: 18.7s	remaining: 5.56s
# 771:	learn: 58.9704487	total: 18.8s	remaining: 5.54s
# 772:	learn: 58.9528724	total: 18.8s	remaining: 5.51s
# 773:	learn: 58.9382423	total: 18.8s	remaining: 5.49s
# 774:	learn: 58.9191041	total: 18.8s	remaining: 5.46s
# 775:	learn: 58.9078172	total: 18.9s	remaining: 5.44s
# 776:	learn: 58.8908899	total: 18.9s	remaining: 5.42s
# 777:	learn: 58.8852639	total: 18.9s	remaining: 5.39s
# 778:	learn: 58.8744707	total: 18.9s	remaining: 5.37s
# 779:	learn: 58.8563797	total: 18.9s	remaining: 5.34s
# 780:	learn: 58.8487891	total: 19s	remaining: 5.32s
# 781:	learn: 58.8411679	total: 19s	remaining: 5.29s
# 782:	learn: 58.8071153	total: 19s	remaining: 5.26s
# 783:	learn: 58.8066968	total: 19s	remaining: 5.24s
# 784:	learn: 58.7875726	total: 19s	remaining: 5.21s
# 785:	learn: 58.7603933	total: 19.1s	remaining: 5.19s
# 786:	learn: 58.7497374	total: 19.1s	remaining: 5.16s
# 787:	learn: 58.7262453	total: 19.1s	remaining: 5.14s
# 788:	learn: 58.7139181	total: 19.1s	remaining: 5.11s
# 789:	learn: 58.6964479	total: 19.1s	remaining: 5.09s
# 790:	learn: 58.6682379	total: 19.2s	remaining: 5.06s
# 791:	learn: 58.6580503	total: 19.2s	remaining: 5.04s
# 792:	learn: 58.6285218	total: 19.2s	remaining: 5.01s
# 793:	learn: 58.6088507	total: 19.2s	remaining: 4.99s
# 794:	learn: 58.5805267	total: 19.2s	remaining: 4.96s
# 795:	learn: 58.5759358	total: 19.3s	remaining: 4.94s
# 796:	learn: 58.5534215	total: 19.3s	remaining: 4.91s
# 797:	learn: 58.5262432	total: 19.3s	remaining: 4.89s
# 798:	learn: 58.5198981	total: 19.3s	remaining: 4.86s
# 799:	learn: 58.4986811	total: 19.4s	remaining: 4.84s
# 800:	learn: 58.4812328	total: 19.4s	remaining: 4.81s
# 801:	learn: 58.4694809	total: 19.4s	remaining: 4.79s
# 802:	learn: 58.4468320	total: 19.4s	remaining: 4.76s
# 803:	learn: 58.4101103	total: 19.4s	remaining: 4.74s
# 804:	learn: 58.4009759	total: 19.5s	remaining: 4.71s
# 805:	learn: 58.3788476	total: 19.5s	remaining: 4.69s
# 806:	learn: 58.3620727	total: 19.5s	remaining: 4.67s
# 807:	learn: 58.3527175	total: 19.6s	remaining: 4.65s
# 808:	learn: 58.3392167	total: 19.6s	remaining: 4.62s
# 809:	learn: 58.3289233	total: 19.6s	remaining: 4.6s
# 810:	learn: 58.3026344	total: 19.6s	remaining: 4.57s
# 811:	learn: 58.2670873	total: 19.7s	remaining: 4.55s
# 812:	learn: 58.2517811	total: 19.7s	remaining: 4.52s
# 813:	learn: 58.2457021	total: 19.7s	remaining: 4.5s
# 814:	learn: 58.2219450	total: 19.7s	remaining: 4.48s
# 815:	learn: 58.2165506	total: 19.7s	remaining: 4.45s
# 816:	learn: 58.1705732	total: 19.8s	remaining: 4.43s
# 817:	learn: 58.1606248	total: 19.8s	remaining: 4.4s
# 818:	learn: 58.1570290	total: 19.8s	remaining: 4.38s
# 819:	learn: 58.1497813	total: 19.8s	remaining: 4.35s
# 820:	learn: 58.1423278	total: 19.9s	remaining: 4.33s
# 821:	learn: 58.1289876	total: 19.9s	remaining: 4.3s
# 822:	learn: 58.1063504	total: 19.9s	remaining: 4.28s
# 823:	learn: 58.0960234	total: 19.9s	remaining: 4.25s
# 824:	learn: 58.0888683	total: 19.9s	remaining: 4.23s
# 825:	learn: 58.0810732	total: 20s	remaining: 4.21s
# 826:	learn: 58.0661505	total: 20s	remaining: 4.18s
# 827:	learn: 58.0357600	total: 20s	remaining: 4.16s
# 828:	learn: 58.0097082	total: 20s	remaining: 4.13s
# 829:	learn: 57.9724935	total: 20.1s	remaining: 4.11s
# 830:	learn: 57.9641195	total: 20.1s	remaining: 4.08s
# 831:	learn: 57.9624884	total: 20.1s	remaining: 4.06s
# 832:	learn: 57.9048922	total: 20.1s	remaining: 4.04s
# 833:	learn: 57.8401852	total: 20.1s	remaining: 4.01s
# 834:	learn: 57.8329214	total: 20.2s	remaining: 3.98s
# 835:	learn: 57.7992181	total: 20.2s	remaining: 3.96s
# 836:	learn: 57.7808764	total: 20.2s	remaining: 3.94s
# 837:	learn: 57.7591302	total: 20.3s	remaining: 3.91s
# 838:	learn: 57.7413088	total: 20.3s	remaining: 3.89s
# 839:	learn: 57.7204409	total: 20.3s	remaining: 3.87s
# 840:	learn: 57.7200448	total: 20.3s	remaining: 3.84s
# 841:	learn: 57.7107195	total: 20.3s	remaining: 3.81s
# 842:	learn: 57.6908552	total: 20.4s	remaining: 3.79s
# 843:	learn: 57.6850634	total: 20.4s	remaining: 3.77s
# 844:	learn: 57.6698382	total: 20.4s	remaining: 3.74s
# 845:	learn: 57.6409265	total: 20.4s	remaining: 3.72s
# 846:	learn: 57.6185033	total: 20.4s	remaining: 3.69s
# 847:	learn: 57.5911536	total: 20.5s	remaining: 3.67s
# 848:	learn: 57.5747772	total: 20.5s	remaining: 3.64s
# 849:	learn: 57.5696893	total: 20.5s	remaining: 3.62s
# 850:	learn: 57.5525493	total: 20.5s	remaining: 3.59s
# 851:	learn: 57.5129375	total: 20.5s	remaining: 3.57s
# 852:	learn: 57.4975425	total: 20.6s	remaining: 3.54s
# 853:	learn: 57.4810007	total: 20.6s	remaining: 3.52s
# 854:	learn: 57.4713663	total: 20.6s	remaining: 3.49s
# 855:	learn: 57.4594971	total: 20.6s	remaining: 3.47s
# 856:	learn: 57.4502101	total: 20.6s	remaining: 3.44s
# 857:	learn: 57.4381424	total: 20.7s	remaining: 3.42s
# 858:	learn: 57.4335139	total: 20.7s	remaining: 3.4s
# 859:	learn: 57.4305491	total: 20.7s	remaining: 3.37s
# 860:	learn: 57.4207141	total: 20.7s	remaining: 3.35s
# 861:	learn: 57.4098381	total: 20.7s	remaining: 3.32s
# 862:	learn: 57.3914159	total: 20.8s	remaining: 3.29s
# 863:	learn: 57.3910398	total: 20.8s	remaining: 3.27s
# 864:	learn: 57.3705852	total: 20.8s	remaining: 3.25s
# 865:	learn: 57.3500357	total: 20.8s	remaining: 3.22s
# 866:	learn: 57.3239368	total: 20.8s	remaining: 3.2s
# 867:	learn: 57.2871667	total: 20.9s	remaining: 3.17s
# 868:	learn: 57.2734113	total: 20.9s	remaining: 3.15s
# 869:	learn: 57.2639029	total: 20.9s	remaining: 3.12s
# 870:	learn: 57.2398756	total: 20.9s	remaining: 3.1s
# 871:	learn: 57.2145163	total: 20.9s	remaining: 3.07s
# 872:	learn: 57.2116057	total: 21s	remaining: 3.05s
# 873:	learn: 57.1922017	total: 21s	remaining: 3.02s
# 874:	learn: 57.1665810	total: 21s	remaining: 3s
# 875:	learn: 57.1630883	total: 21s	remaining: 2.98s
# 876:	learn: 57.1453617	total: 21s	remaining: 2.95s
# 877:	learn: 57.1375225	total: 21.1s	remaining: 2.93s
# 878:	learn: 57.1090456	total: 21.1s	remaining: 2.9s
# 879:	learn: 57.0868187	total: 21.1s	remaining: 2.88s
# 880:	learn: 57.0763563	total: 21.1s	remaining: 2.85s
# 881:	learn: 57.0562789	total: 21.1s	remaining: 2.83s
# 882:	learn: 57.0436932	total: 21.2s	remaining: 2.8s
# 883:	learn: 57.0433666	total: 21.2s	remaining: 2.78s
# 884:	learn: 57.0349859	total: 21.2s	remaining: 2.75s
# 885:	learn: 56.9997008	total: 21.2s	remaining: 2.73s
# 886:	learn: 56.9908198	total: 21.2s	remaining: 2.71s
# 887:	learn: 56.9814878	total: 21.3s	remaining: 2.68s
# 888:	learn: 56.9698321	total: 21.3s	remaining: 2.66s
# 889:	learn: 56.9439890	total: 21.3s	remaining: 2.63s
# 890:	learn: 56.9341826	total: 21.3s	remaining: 2.61s
# 891:	learn: 56.8923113	total: 21.4s	remaining: 2.59s
# 892:	learn: 56.8630826	total: 21.4s	remaining: 2.56s
# 893:	learn: 56.8607811	total: 21.5s	remaining: 2.54s
# 894:	learn: 56.8521109	total: 21.5s	remaining: 2.52s
# 895:	learn: 56.8334083	total: 21.5s	remaining: 2.5s
# 896:	learn: 56.8230861	total: 21.5s	remaining: 2.47s
# 897:	learn: 56.8077418	total: 21.6s	remaining: 2.45s
# 898:	learn: 56.7865940	total: 21.6s	remaining: 2.42s
# 899:	learn: 56.7710412	total: 21.6s	remaining: 2.4s
# 900:	learn: 56.7449648	total: 21.6s	remaining: 2.38s
# 901:	learn: 56.7294756	total: 21.7s	remaining: 2.35s
# 902:	learn: 56.7194143	total: 21.7s	remaining: 2.33s
# 903:	learn: 56.7067823	total: 21.7s	remaining: 2.31s
# 904:	learn: 56.6709965	total: 21.7s	remaining: 2.28s
# 905:	learn: 56.6458395	total: 21.8s	remaining: 2.26s
# 906:	learn: 56.6376463	total: 21.8s	remaining: 2.23s
# 907:	learn: 56.6157711	total: 21.8s	remaining: 2.21s
# 908:	learn: 56.6092696	total: 21.8s	remaining: 2.19s
# 909:	learn: 56.5900388	total: 21.9s	remaining: 2.16s
# 910:	learn: 56.5656766	total: 21.9s	remaining: 2.14s
# 911:	learn: 56.5461409	total: 21.9s	remaining: 2.11s
# 912:	learn: 56.5406231	total: 21.9s	remaining: 2.09s
# 913:	learn: 56.5283757	total: 22s	remaining: 2.06s
# 914:	learn: 56.4980218	total: 22s	remaining: 2.04s
# 915:	learn: 56.4781165	total: 22s	remaining: 2.02s
# 916:	learn: 56.4623388	total: 22s	remaining: 1.99s
# 917:	learn: 56.4444043	total: 22.1s	remaining: 1.97s
# 918:	learn: 56.3999639	total: 22.1s	remaining: 1.95s
# 919:	learn: 56.3798551	total: 22.2s	remaining: 1.93s
# 920:	learn: 56.3560728	total: 22.2s	remaining: 1.9s
# 921:	learn: 56.3163287	total: 22.2s	remaining: 1.88s
# 922:	learn: 56.2974720	total: 22.3s	remaining: 1.86s
# 923:	learn: 56.2818049	total: 22.3s	remaining: 1.83s
# 924:	learn: 56.2717090	total: 22.3s	remaining: 1.81s
# 925:	learn: 56.2564824	total: 22.3s	remaining: 1.78s
# 926:	learn: 56.2464188	total: 22.4s	remaining: 1.76s
# 927:	learn: 56.2268226	total: 22.4s	remaining: 1.74s
# 928:	learn: 56.2121085	total: 22.4s	remaining: 1.71s
# 929:	learn: 56.1899862	total: 22.4s	remaining: 1.69s
# 930:	learn: 56.1777505	total: 22.5s	remaining: 1.66s
# 931:	learn: 56.1684729	total: 22.5s	remaining: 1.64s
# 932:	learn: 56.1553260	total: 22.5s	remaining: 1.62s
# 933:	learn: 56.1450911	total: 22.5s	remaining: 1.59s
# 934:	learn: 56.1360323	total: 22.6s	remaining: 1.57s
# 935:	learn: 56.1188004	total: 22.6s	remaining: 1.54s
# 936:	learn: 56.1110303	total: 22.6s	remaining: 1.52s
# 937:	learn: 56.1002552	total: 22.6s	remaining: 1.5s
# 938:	learn: 56.0899788	total: 22.7s	remaining: 1.47s
# 939:	learn: 56.0721840	total: 22.7s	remaining: 1.45s
# 940:	learn: 56.0612256	total: 22.7s	remaining: 1.42s
# 941:	learn: 56.0482488	total: 22.7s	remaining: 1.4s
# 942:	learn: 56.0459932	total: 22.8s	remaining: 1.38s
# 943:	learn: 56.0278420	total: 22.8s	remaining: 1.35s
# 944:	learn: 56.0068824	total: 22.8s	remaining: 1.33s
# 945:	learn: 55.9922114	total: 22.8s	remaining: 1.3s
# 946:	learn: 55.9884508	total: 22.8s	remaining: 1.28s
# 947:	learn: 55.9754764	total: 22.9s	remaining: 1.25s
# 948:	learn: 55.9694414	total: 22.9s	remaining: 1.23s
# 949:	learn: 55.9543490	total: 22.9s	remaining: 1.21s
# 950:	learn: 55.9432462	total: 23s	remaining: 1.18s
# 951:	learn: 55.9234753	total: 23s	remaining: 1.16s
# 952:	learn: 55.9034288	total: 23s	remaining: 1.13s
# 953:	learn: 55.8846700	total: 23s	remaining: 1.11s
# 954:	learn: 55.8629829	total: 23.1s	remaining: 1.09s
# 955:	learn: 55.8417029	total: 23.1s	remaining: 1.06s
# 956:	learn: 55.8284344	total: 23.1s	remaining: 1.04s
# 957:	learn: 55.8189025	total: 23.1s	remaining: 1.01s
# 958:	learn: 55.7899617	total: 23.2s	remaining: 990ms
# 959:	learn: 55.7818815	total: 23.2s	remaining: 966ms
# 960:	learn: 55.7670397	total: 23.2s	remaining: 942ms
# 961:	learn: 55.7486108	total: 23.2s	remaining: 918ms
# 962:	learn: 55.7336881	total: 23.3s	remaining: 894ms
# 963:	learn: 55.7264648	total: 23.3s	remaining: 870ms
# 964:	learn: 55.7070462	total: 23.3s	remaining: 845ms
# 965:	learn: 55.6959135	total: 23.3s	remaining: 821ms
# 966:	learn: 55.6772326	total: 23.4s	remaining: 797ms
# 967:	learn: 55.6683663	total: 23.4s	remaining: 773ms
# 968:	learn: 55.6639936	total: 23.4s	remaining: 749ms
# 969:	learn: 55.6425965	total: 23.4s	remaining: 725ms
# 970:	learn: 55.6358563	total: 23.5s	remaining: 701ms
# 971:	learn: 55.6270250	total: 23.5s	remaining: 677ms
# 972:	learn: 55.6154765	total: 23.5s	remaining: 652ms
# 973:	learn: 55.5979474	total: 23.5s	remaining: 628ms
# 974:	learn: 55.5758323	total: 23.6s	remaining: 604ms
# 975:	learn: 55.5458757	total: 23.6s	remaining: 580ms
# 976:	learn: 55.5283061	total: 23.6s	remaining: 556ms
# 977:	learn: 55.5107068	total: 23.6s	remaining: 532ms
# 978:	learn: 55.5049981	total: 23.7s	remaining: 507ms
# 979:	learn: 55.4847032	total: 23.7s	remaining: 483ms
# 980:	learn: 55.4750497	total: 23.7s	remaining: 459ms
# 981:	learn: 55.4528324	total: 23.7s	remaining: 435ms
# 982:	learn: 55.4239077	total: 23.8s	remaining: 411ms
# 983:	learn: 55.4115472	total: 23.8s	remaining: 387ms
# 984:	learn: 55.4078924	total: 23.8s	remaining: 363ms
# 985:	learn: 55.4074909	total: 23.8s	remaining: 339ms
# 986:	learn: 55.3560268	total: 23.9s	remaining: 314ms
# 987:	learn: 55.3283294	total: 23.9s	remaining: 290ms
# 988:	learn: 55.3120057	total: 23.9s	remaining: 266ms
# 989:	learn: 55.3005127	total: 24s	remaining: 242ms
# 990:	learn: 55.2839677	total: 24s	remaining: 218ms
# 991:	learn: 55.2716484	total: 24s	remaining: 194ms
# 992:	learn: 55.2575627	total: 24s	remaining: 170ms
# 993:	learn: 55.2502370	total: 24.1s	remaining: 145ms
# 994:	learn: 55.2390934	total: 24.1s	remaining: 121ms
# 995:	learn: 55.2259236	total: 24.1s	remaining: 96.9ms
# 996:	learn: 55.2160223	total: 24.1s	remaining: 72.6ms
# 997:	learn: 55.1915653	total: 24.2s	remaining: 48.4ms
# 998:	learn: 55.1767610	total: 24.2s	remaining: 24.2ms
# 999:	learn: 55.1543863	total: 24.2s	remaining: 0us

# %%
y_train_pred = catboost_regr.predict(train_X)
mae = mean_absolute_error(train_y, y_train_pred)
mse = mean_squared_error(train_y, y_train_pred)
r2 = r2_score(train_y, y_train_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 32.05790573429074
# Mean Squared Error: 3042.006330333057
# R-squared: 0.8282446721392478

# %% [markdown]
# ## Test set, without label

# %%
import pandas as pd

test_df = pd.read_csv('test.csv')
# Out:
# /tmp/ipykernel_497/3100640438.py:3: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_df = pd.read_csv('test.csv')

# %%
df_test = test_df.copy()

# %%
df_test['host_since_year'] = pd.to_datetime(df_test['host_since']).dt.year
df_test['host_since_month'] = pd.to_datetime(df_test['host_since']).dt.month
df_test['host_since_day'] = pd.to_datetime(df_test['host_since']).dt.day

df_test['first_re_year'] = pd.to_datetime(df_test['first_review']).dt.year
df_test['last_re_year'] = pd.to_datetime(df_test['last_review']).dt.year
df_test['first_re_month'] = pd.to_datetime(df_test['first_review']).dt.month
df_test['last_re_month'] = pd.to_datetime(df_test['last_review']).dt.month
df_test['first_re_day'] = pd.to_datetime(df_test['first_review']).dt.day
df_test['last_re_day'] = pd.to_datetime(df_test['last_review']).dt.day

# %%
new_columns_data = {}
for idx, amenity in enumerate(all_amenities, start=1):
    new_columns_data[f'amenity_{idx}'] = df_test['amenities'].apply(lambda x: 1 if amenity in x else 0)

df_test = pd.concat([df_test, pd.DataFrame(new_columns_data)], axis=1)

# %%
veri_columns_data = {}
for idx, veri in enumerate(all_verifications, start=1):
    veri_columns_data[f'veri_{idx}'] = df_test['host_verifications'].apply(lambda x: 1 if (isinstance(x, str) and veri in x) 
                                                                         else 0 if pd.isnull(x) else 0)

df_test = pd.concat([df_test, pd.DataFrame(veri_columns_data)], axis=1)

# %%
test_ids, test_X = [], []
for (idx, row) in df_test.iterrows():
    feature = create_feature(row)
    test_ids.append(row.id)
    test_X.append(feature)
test_y = catboost_regr.predict(test_X)

# %%
print(len(test_y))
# Out:
# 17337

# %%
output_df = pd.DataFrame()
output_df['Id'] = test_ids
output_df['Predicted'] = test_y
output_df.to_csv('catboost_regression_baseline.csv', index = False)
